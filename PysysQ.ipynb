# %% [markdown]
# As a first step check the python version

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %% [markdown]
# Expected python version must be 3.10 or above. The recommended python version is 3.

# %% [markdown]
# Install pysysq package

# %%
# !pip install pysysq
# Out:
# ...
#   Obtaining dependency information for pysysq from https://files.pythonhosted.org/packages/06/51/3e61c19accc6dcd3c26b8862f85d5d23eab2c2512aafc2fb7a1339cd06f5/pysysq-0.0.5-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 2.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# When the pysysq package installation is successful we can generate the simulation setup. If you would like to check if the code is working fine , generate the default simulation setup with the below code
#
# In case you want to use a custom json file use the below code
# ```python
# from pysysq import *
# SQSimSetupGen(json_file='/path/to/json').generate('/path/to/output_folder')
# ```

# %%
from pysysq import *
SQSimSetupGen().generate('output')
# Out:
# FilterFactory
# Done

# %% [markdown]
# Now you can go to the output folder to view the generated

# %%
# !ls -a
# Out:
# .      dist	   .idea	       output	       README.md	 src
# ..     .git	   .ipynb_checkpoints  pyproject.toml  requirements.txt  tests
# build  .gitignore  LICENSE	       PysysQ.ipynb    simulation.log	 venv

# %% [markdown]
# Go to the output folder to view the generated files

# %%
# !cd output
# !ls -a
# Out:
# .      dist	   .idea	       output	       README.md	 src
# ..     .git	   .ipynb_checkpoints  pyproject.toml  requirements.txt  tests
# build  .gitignore  LICENSE	       PysysQ.ipynb    simulation.log	 venv

# %%
# !ls ./output
# Out:
# filterfactory.py  filterhelperfactory.py  pktsimulator_setup.py

# %%
# !python output/pktsimulator_setup.py
# Out:
# 2024-03-24 18:48:24,735 - SQSimulator - [INFO]  - PktSimulator::0:: init
# 2024-03-24 18:48:24,736 - SQClock - [INFO]  - Clock::0:: init
# 2024-03-24 18:48:24,736 - SQPacketGenerator - [INFO]  - Generator::0:: init
# 2024-03-24 18:48:24,736 - SQSingleQueue - [INFO]  - Pkt_q::0:: init
# 2024-03-24 18:48:24,736 - SQPktProcessor - [INFO]  - Processor1::0:: init
# 2024-03-24 18:48:24,736 - SQSingleQueue - [INFO]  - Proc_q::0:: init
# 2024-03-24 18:48:24,736 - SQFilter - [INFO]  - Filter::0:: init
# 2024-03-24 18:48:24,736 - SQSingleQueue - [INFO]  - Filter_q::0:: init
# 2024-03-24 18:48:24,736 - SQPktProcessor - [INFO]  - Processor2::0:: init
# 2024-03-24 18:48:24,736 - SQSingleQueue - [INFO]  - Sink_q::0:: init
# 2024-03-24 18:48:24,736 - SQPktSink - [INFO]  - Terminator::0:: init
# 2024-03-24 18:48:24,736 - SQSimulator - [INFO]  - PktSimulator::0:: start
# 2024-03-24 18:48:24,736 - SQClock - [INFO]  - Clock::0:: start
# ...

# %%
from IPython.display import Image
Image(filename='Processor1.png')

# %%
from IPython.display import Image
Image(filename='Processor2.png')

# %%
from IPython.display import Image
Image(filename='Filter_q.png')

# %%
from IPython.display import Image
Image(filename='Pkt_q.png')

# %%
from IPython.display import Image
Image(filename='Proc_q.png')

# %%
from IPython.display import Image
Image(filename='Sink_q.png')
